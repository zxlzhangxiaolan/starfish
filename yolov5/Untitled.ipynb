# %%
# !python train.py --weights yolov5s.pt --cfg models/yolov5s.yaml --data data/cots.yaml --workers 6 --batch-size 16 --epochs 100
# Out:
# train: weights=yolov5s.pt, cfg=models/yolov5s.yaml, data=data/cots.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=6, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# YOLOv5 🚀 v6.2-239-gf33718f Python-3.8.10 torch-1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12054MiB)
#
# ...

# %%
# !python test.py --cfg models/yolov5-bifpn.yaml
# Out:
# device: cuda:0
# the model of 'models/yolov5-bifpn.yaml' is :
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
# ...

# %%
# !python train.py --weights yolov5s.pt --cfg models/yolov5-bifpn.yaml --data data/cots.yaml --workers 6 --batch-size 16 --epochs 100
# Out:
# train: weights=yolov5s.pt, cfg=models/yolov5-bifpn.yaml, data=data/cots.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=6, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 51 (delta 31), reused 37 (delta 19), pack-reused 0
# Unpacking objects: 100% (51/51), done.
# From https://github.com/ultralytics/yolov5
#    abbfd69..ea73386  master     -> origin/master
# ...

# %%
# !python val.py --data data/cots.yaml --weights best.pt
# Out:
# val: data=data/cots.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-239-gf33718f Python-3.8.10 torch-1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12054MiB)
#
# Fusing layers...
# YOLOv5-bifpn summary: 510 layers, 29223526 parameters, 0 gradients, 59.8 GFLOPs
# val: Scanning '/root/yolov5/yolov5/data/cots/labels/val.cache' images and labels
#                  Class     Images  Instances          P          R      MAP50
#                  all        984       2389      0.889      0.895      0.987      0.664
# conf:0.421
# f2-score:0.6921126088134353
# Speed: 0.3ms pre-process, 3.9ms inference, 1.8ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp22

# %%
# !python detect.py --weights yolo5s-best.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['yolo5s-best.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-239-gf33718f Python-3.8.10 torch-1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12054MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2 /root/yolov5/yolov5/data/images/Cots-2.jpg: 384x640 2 Barrier Reefs, 16.6ms
# image 2/2 /root/yolov5/yolov5/data/images/Cots.jpg: 384x640 1 Barrier Reef, 11.1ms
# Speed: 0.3ms pre-process, 13.9ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
# !python detect.py --weights best.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['best.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-239-gf33718f Python-3.8.10 torch-1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12054MiB)
#
# Fusing layers...
# YOLOv5-bifpn summary: 510 layers, 29223526 parameters, 0 gradients, 59.8 GFLOPs
# image 1/2 /root/yolov5/yolov5/data/images/Cots-2.jpg: 384x640 2 Barrier Reefs, 29.5ms
# image 2/2 /root/yolov5/yolov5/data/images/Cots.jpg: 384x640 1 Barrier Reef, 26.3ms
# Speed: 0.3ms pre-process, 27.9ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
